# %%
import pymysql

db_config = { 
    'user' :"chanseam" ,
    'password' : 'qwe123!@#',
    'host' : "192.168.123.160",
    'port' : 4000,
    'database': 'test'
}
conn = pymysql.connect(**db_config)
cursor = conn.cursor()
cursor.execute('show databases')
# Out:
# 3

# %%
import pandas as pd
from sklearn .datasets import load_iris
x , y = load_iris(return_X_y=True, as_frame=True)
df = pd.concat([x,y], axis='columns')

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS iris_data (
    id SERIAL PRIMARY KEY,
    timestamp timestamp,
    sepal_length float,
    sepal_width float,
    petal_length float,
    petal_width float,
    target int
)
"""

# %%
with conn.cursor() as cur:
    cur.execute(create_table_query)
    conn.commit()

# %%
db_connect = pymysql.connect(**db_config)
def create_table(db_connect):
    create_table_query = """
    CREATE TABLE IF NOT EXISTS iris_data (
        id SERIAL PRIMARY KEY,
        timestamp timestamp,
        sepal_length float,
        sepal_width float,
        petal_length float,
        petal_width float,
        target int
    )
    """
    print(create_table_query)
    with db_connect.cursor() as cur:
        cur.execute(create_table_query)
        db_connect.commit()

# %%
if __name__ == "__main__":
    db_config = { 
    'user' :"chanseam" ,
    'password' : 'qwe123!@#',
    'host' : "192.168.0.25",
    'port' : 4000,
    'database': 'test'
    }
    db_connect = pymysql.connect(**db_config)
    create_table(db_connect)
# Out:
#     CREATE TABLE IF NOT EXISTS iris_data (
#         id SERIAL PRIMARY KEY,
#         timestamp timestamp,
#         sepal_length float,
#         sepal_width float,
#         petal_length float,
#         petal_width float,
#         target int
#     )

# %% [markdown]
# # data insertion

# %%
import pandas as pd
from sklearn.datasets import load_iris

X,y, = load_iris(return_X_y=True, as_frame=True)
df = pd.concat([X,y], axis = 'columns')
rename_rule = {
    "sepal length (cm)" : "sepal_length",
    "sepal width (cm)"  : "sepal_width",
    "petal length (cm)" : "petal_length",
    "petal width (cm)"  : "petal width",
}
df = df.rename(columns = rename_rule)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal width (cm)  target
# 0             5.1          3.5           1.4               0.2       0
# 1             4.9          3.0           1.4               0.2       0
# 2             4.7          3.2           1.3               0.2       0
# 3             4.6          3.1           1.5               0.2       0
# 4             5.0          3.6           1.4               0.2       0
# ..            ...          ...           ...               ...     ...
# 145           6.7          3.0           5.2               2.3       2
# 146           6.3          2.5           5.0               1.9       2
# 147           6.5          3.0           5.2               2.0       2
# 148           6.2          3.4           5.4               2.3       2
# 149           5.9          3.0           5.1               1.8       2
#
# [150 rows x 5 columns]

# %%
def get_data():
    X, y = load_iris(return_X_y=True, as_frame=True)
    df = pd.concat([X,y],axis="columns")
    rename_rule = {
    "sepal length (cm)" : "sepal_length",
    "sepal width (cm)"  : "sepal_width",
    "petal length (cm)" : "petal_length",
    "petal width (cm)"  : "petal width",
    }
    df = df.rename(columns = rename_rule)
    return df

# %%
data = df.sample(1).squeeze()

# %%
insert_row_query = f"""
INSERT INTO iris_data
    (timestamp, sepal_length, sepal_width, petal_length, petal_width, target)
    VALUES (
        NOW(),
        {data.sepal_length},
        {data.sepal_width},
        {data.petal_length},
        {data.petal_width},
        {data.tartget}
    )
"""

# %%
def insert_data(db_connect, data):
    insert_row_query = f"""
    INSERT INTO iris_data
        (timestamp, sepal_length, sepal_width, petal_length, petal_width, target)
        VALUES (
            NOW(),
            {data.sepal_length},
            {data.sepal_width},
            {data.petal_length},
            {data.petal_width},
            {data.tartget}
        )
    """
    print(insert_row_query)
    with db_connect.cursor() as cur:
        cur.execute(insert_row_query)
        db_connect.commit()

# %%
import pandas as pd
import pymysql
from sklearn.datasets import load_iris
import time

def get_data():
    X, y = load_iris(return_X_y=True, as_frame=True)
    df = pd.concat([X,y],axis="columns")
    rename_rule = {
    "sepal length (cm)" : "sepal_length",
    "sepal width (cm)"  : "sepal_width",
    "petal length (cm)" : "petal_length",
    "petal width (cm)"  : "petal_width",
    }
    df = df.rename(columns = rename_rule)
    return df


def insert_data(db_connect, data):
    insert_row_query = f"""
    INSERT INTO iris_data
        (timestamp, sepal_length, sepal_width, petal_length, petal_width, target)
        VALUES (
            NOW(),
            {data.sepal_length},
            {data.sepal_width},
            {data.petal_length},
            {data.petal_width},
            {data.target}
        )
    """
    print(insert_row_query)
    with db_connect.cursor() as cur:
        cur.execute(insert_row_query)
        db_connect.commit()

if __name__ =="__main__":
    db_config = { 
    'user' :"chanseam" ,
    'password' : 'qwe123!@#',
    'host' : "192.168.0.25",
    'port' : 4000,
    'database': 'test'
    }
    db_connect = pymysql.connect(**db_config)
    df = get_data()
    insert_data(db_connect, df.sample(1).squeeze())
# Out:
#     INSERT INTO iris_data
#         (timestamp, sepal_length, sepal_width, petal_length, petal_width, target)
#         VALUES (
#             NOW(),
#             6.5,
#             3.0,
#             5.8,
#             2.2,
#             2.0
#         )

# %%
def generate_data(db_connect,df):
    while True : 
        insert_data(db_connect, df.sample(1).squeeze())
        time.sleep(1)

# %%
type(df.sample(1).squeeze())
# Out:
# pandas.core.series.Series

# %%
type(df.sample(1))
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import pymysql
db_config = { 
    'user' :"chanseam" ,
    'password' : 'qwe123!@#',
    'host' : "192.168.0.25",
    'port' : 4000,
    'database': 'test'
    }
db_connect = pymysql.connect(**db_config)
df = pd.read_sql("select * from iris_data order by id DESC limit 100",db_connect)
df
# Out:
# /tmp/ipykernel_3236/1688356582.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from iris_data order by id DESC limit 100",db_connect)
#       id           timestamp  sepal_length  sepal_width  petal_length  \
# 0   1397 2024-04-25 05:24:09           6.1          2.8           4.7
# 1   1396 2024-04-25 05:24:08           5.2          3.4           1.4
# 2   1395 2024-04-25 05:24:07           6.4          2.8           5.6
# 3   1394 2024-04-25 05:24:06           5.0          2.0           3.5
# 4   1393 2024-04-25 05:24:05           7.7          2.8           6.7
# ..   ...                 ...           ...          ...           ...
# 95  1302 2024-04-25 05:22:09           5.7          2.8           4.5
# 96  1301 2024-04-25 05:22:08           5.8          2.7           4.1
# 97  1300 2024-04-25 05:22:07           6.5          3.0           5.5
# 98  1299 2024-04-25 05:22:06           6.0          2.2           4.0
# 99  1298 2024-04-25 05:22:05           6.5          2.8           4.6
#
#     petal_width  target
# 0           1.2       1
# 1           0.2       0
# 2           2.1       2
# 3           1.0       1
# 4           2.0       2
# ..          ...     ...
# 95          1.3       1
# 96          1.0       1
# 97          1.8       2
# 98          1.0       1
# 99          1.5       1
#
# [100 rows x 7 columns]

# %%
ls
# Out:
# Dockerfile         data_insertion.py       docker-compose.yaml  test.ipynb
# data_generator.py  data_insertion_loop.py  table_creator.py

# %%
import datetime

# %%
a = datetime.timedelta(1)

# %%
a
# Out:
# datetime.timedelta(days=1)

# %%
datetime.datetime.now()-a
# Out:
# datetime.datetime(2024, 5, 16, 9, 25, 12, 488386)
